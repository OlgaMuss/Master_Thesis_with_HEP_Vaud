# %% [markdown]
# ---
# title: "Master Thesis - Links and Resources"
# author: "Olga Muss Laurenty"
# date: "2026-01-21"
# format:
#   html:
#     toc: true
#     toc-depth: 3
#   pdf:
#     toc: true
# bibliography: references__validation_required.bib
# csl: apa.csl
# ---

# %% [markdown]
# # Shared Drive
#
# - [Main Drive Folder](https://drive.google.com/drive/folders/1ydsIYtM8FqHpcXSpY9I1zw6ruoluz9w4)

# %% [markdown]
# ## Working Documents
# - [Draft cadrage devoirs](https://docs.google.com/document/d/1xSpZ45iX40Az5iINTb4JHVeu_J1pshSOLfDHqHE4MLc/edit?tab=t.0#heading=h.vmzttc6vv4g6)
# - [LLM safeguards canva](https://www.canva.com/design/DAGyv90q0uA/TEQ9J5xEBm9JXcIeb_1tuw/edit)
# - [workshop description in canva](https://www.canva.com/design/DAG50Bhfheo/LvwrS6W8hO6Yriz-856Srw/edit)

# %% [markdown]
# ## Autres documents
# - [Cours Morgane](https://drive.google.com/drive/folders/1ydsIYtM8FqHpcXSpY9I1zw6ruoluz9w4)
# - [Literature review slides](https://docs.google.com/presentation/d/1hqslgG48gWDHnaaZTgZGd1RYVsFeiRmCmJIj-eDuzGM/edit?slide=id.g3b142f78736_0_42#slide=id.g3b142f78736_0_42)
#
# # Swiss Educational Policy (CIIP)
# - [Recommandations CIIP sur l'IA générative](https://www.ciip.ch/files/1050/Documents/IRDP/Recommandations_IAG_19-03-2025_V10.pdf)
# - [modeles didactiques (dimensions)](https://www.ciip.ch/files/66/Documents/Ressources-pedagogiques/MD_Description_des_modeles.pdf)
# - [semaine des medias 2024 - la web serie RTS - 3 min pour comprendre l'IA](https://www.e-media.ch/events/La-Semaine-des-medias-2024-3-minutes-pour-comprendre-lintelligence-artificielle)
# - [L’évaluation de la résolution de problèmes en mathématiques](https://www.ciip.ch/Document/Levaluation-de-la-resolution-de-probleme/2214)
#
# # Educational Tools & Platforms
# - [That's AI](https://www.thats-ai.org/) - Educational resources about AI
# - [GRAASP](https://graasp.org/) - Swiss educational platform
